# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello, World!") #This is a comment
# Out:
# Hello, World!

# %%
#Camel Case
myVariableName = "John"
#Pascal Case
MyVariableName = "John"
#Snake Case
my_variable_name = "John"

# %%
#Part A — Python basics
print("Sam")
print("System Developer Python and AI")
print("Goal: Learn Python variables")
# Out:
# Sam
# System Developer Python and AI
# Goal: Learn Python variables

# %%
#Variables
name = "Sam"
age = 35
height = 1.65
is_student = True
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))

# %%
#Python variables can change type
value = 100

print(value)
print(type(value))

value = "one hundred"

print(value)
print(type(value))

# %%
# Airthmetic Operators
print(10 + 5)  # Addition
print(10 - 5)  # Subtraction
print(10 * 5)  # Multiplication
print(10 / 5)  # Division
print(10 % 3)  # Modulus
print(10 ** 2) # Exponentiation
# Out:
# 15
# 5
# 50
# 2.0
# 1
# 100

# %%
a=10
b=3
#print("Multiplication:", a * b)
#print("Floor division:", a // b)
print("Modulus:", a % b)
# Out:
# Modulus: 1

# %%
print("Exponent:", a ** b)
# Out:
# Exponent: 1000

# %%
#Type conversion
#String → Integer
age = "30"

print(type(age))

age = int(age)

print(type(age))

# %%
a = '6'
b = '7'
c = a+b
print(c*2)
# Out:
# 6767

# %%
# Integer → Float
a = 5
b = float(a)
print(b)

# %%
# Number → String
a = 5
b = str(a)
print(b)

# %%
# Part B — User input
username = input("What is your name? ") 
print(username)

# %%
# Calculate age from birth year
current_year = 2026
name =input("what is your name?")
birth_year = int(input("what is bith year?"))
age = current_year - birth_year
print(name,"is appoximately", age,"years old.")
# Out:
# Saimuthukumar is appoximately 10 years old.
